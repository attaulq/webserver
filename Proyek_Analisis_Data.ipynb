# %% [markdown]
# <a href="https://colab.research.google.com/github/attaulq/webserver/blob/update-documentation/Proyek_Analisis_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyek Analisis Data: E-commerce-public-dataset
# - **Email:** atta.ulq@gmail.com
# - **ID Dicoding:** attaulq

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana efektivitas diskon 20% terhadap penjualan produk kategori elektronik selama kuartal terakhir?
# - Apa faktor utama yang mempengaruhi rating kepuasan pelanggan di platform e-commerce berdasarkan ulasan produk?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %% [markdown]
# ## Data Wrangling
#  df['final_price'] = df['revenue'] * (1 - df['discount'] / 100)
#  grouped_data = df.groupby('sale_date').agg({'sale_amount': 'sum', 'final_price': 'sum'}).reset_index()
#  df['sentiment_score'] = df['review_text'].apply(lambda x: analyze_sentiment(x))  # Fungsi analisis sentimen
#       grouped_reviews = df.groupby('product_id').agg({
#          'rating': 'mean',
#          'delivery_time': 'mean',
#          'product_quality': 'mean',
#          'customer_service': 'mean',
#          'sentiment_score': 'mean'
#      }).reset_index()
#
#   import pandas as pd
#
# # Pertanyaan 1: Efektivitas Diskon
# # Membaca data penjualan
# sales_data = pd.read_csv('sales_data.csv')
#
# # Pembersihan Data
# sales_data.drop_duplicates(inplace=True)
# sales_data = sales_data[sales_data['category'] == 'elektronik']
# sales_data.fillna(0, inplace=True)
#
# # Transformasi Data
# sales_data['final_price'] = sales_data['revenue'] * (1 - sales_data['discount'] / 100)
# grouped_sales = sales_data.groupby('sale_date').agg({'sale_amount': 'sum', 'final_price': 'sum'}).reset_index()
#
# # Pertanyaan 2: Faktor Kepuasan Pelanggan
# # Membaca data ulasan
# reviews_data = pd.read_csv('reviews_data.csv')
#
# # Pembersihan Data
# reviews_data.drop_duplicates(inplace=True)
# reviews_data.fillna(reviews_data.mean(), inplace=True)
#
# # Transformasi Data
# reviews_data['sentiment_score'] = reviews_data['review_text'].apply(lambda x: analyze_sentiment(x))
# grouped_reviews = reviews_data.groupby('product_id').agg({
#     'rating': 'mean',
#     'delivery_time': 'mean',
#     'product_quality': 'mean',
#     'customer_service': 'mean',
#     'sentiment_score': 'mean'
# }).reset_index()

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# 1.
# Memahami Dataset:
# Tampilkan beberapa baris pertama dari dataset untuk memahami struktur dan jenis data.
# python
#
#    print(sales_data.head())
# Statistik Deskriptif:
# Hitung statistik deskriptif untuk kolom numerik seperti sale_amount, revenue, dan final_price.
# python
#
#    print(sales_data.describe())
# Distribusi Penjualan:
# Visualisasikan distribusi penjualan sebelum dan sesudah diskon menggunakan histogram atau boxplot.
# python
#
#    import matplotlib.pyplot as plt
#    import seaborn as sns
#
#    plt.figure(figsize=(12, 6))
#    sns.histplot(sales_data['final_price'], bins=30, kde=True)
#    plt.title('Distribusi Harga Akhir Setelah Diskon')
#    plt.xlabel('Harga Akhir')
#    plt.ylabel('Frekuensi')
#    plt.show()
# Tren Penjualan Waktu:
# Buat grafik garis untuk menunjukkan tren penjualan dari waktu ke waktu, baik sebelum maupun sesudah diskon.
# python
#
#    plt.figure(figsize=(12, 6))
#    plt.plot(grouped_sales['sale_date'], grouped_sales['sale_amount'], marker='o')
#    plt.title('Tren Penjualan Kategori Elektronik')
#    plt.xlabel('Tanggal')
#    plt.ylabel('Jumlah Penjualan')
#    plt.xticks(rotation=45)
#    plt.show()
# Analisis Perbandingan:
# Bandingkan rata-rata penjualan sebelum dan sesudah diskon menggunakan analisis t-test untuk menentukan signifikansi.
# python
#
#    from scipy import stats
#
#    before_discount = sales_data[sales_data['discount'] == 0]['final_price']
#    after_discount = sales_data[sales_data['discount'] == 20]['final_price']
#    t_stat, p_value = stats.ttest_ind(before_discount, after_discount)
#    print(f'T-statistic: {t_stat}, P-value: {p_value}')
#
#
# 2.
# Memahami Dataset:
# Tampilkan beberapa baris pertama dari dataset ulasan untuk memahami struktur dan jenis data.
# python
#
#    print(reviews_data.head())
# Statistik Deskriptif:
# Hitung statistik deskriptif untuk kolom numerik seperti rating, delivery_time, product_quality, dan customer_service.
# python
#
#    print(reviews_data.describe())
# Distribusi Rating:
# Visualisasikan distribusi rating menggunakan histogram atau boxplot.
# python
#
#    plt.figure(figsize=(12, 6))
#    sns.histplot(reviews_data['rating'], bins=5, kde=True)
#    plt.title('Distribusi Rating Pelanggan')
#    plt.xlabel('Rating')
#    plt.ylabel('Frekuensi')
#    plt.show()
# Korelasi Antara Variabel:
# Hitung dan visualisasikan matriks korelasi untuk melihat hubungan antara rating dan faktor-faktor lain.
# python
#
#    correlation_matrix = reviews_data[['rating', 'delivery_time', 'product_quality', 'customer_service']].corr()
#    plt.figure(figsize=(10, 8))
#    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
#    plt.title('Matriks Korelasi')
#    plt.show()
# Analisis Sentimen:
# Tampilkan beberapa contoh ulasan dengan skor sentimen positif dan negatif untuk memahami konteks.
# python
#
#    positive_reviews = reviews_data[reviews_data['sentiment_score'] > 0.5]
#    negative_reviews = reviews_data[reviews_data['sentiment_score'] < 0.5]
#    print("Contoh Ulasan Positif:")
#    print(positive_reviews['review_text'].sample(5))
#    print("Contoh Ulasan Negatif:")
#    print(negative_reviews['review_text'].sample(5))
# Visualisasi Hubungan:
# Buat scatter plot untuk menunjukkan hubungan antara rating dan faktor-faktor lain seperti delivery_time dan product_quality.
# python
#
#    plt.figure(figsize=(12, 6))
#    sns.scatterplot(data=reviews_data, x='delivery_time', y='rating', hue='product_quality', palette='viridis')
#    plt.title('Hubungan Antara Waktu Pengiriman dan Rating')
#    plt.xlabel('Waktu Pengiriman')
#    plt.ylabel('Rating')
#    plt.show()

# %% [markdown]
# ### Explore ...

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Visualization & Explanatory Analysis
# 1. Visualisasi untuk Pertanyaan 1: Efektivitas Diskon 20% terhadap Penjualan Produk Kategori Elektronik
# a. Grafik Garis Tren Penjualan
# Visualisasi:
# Grafik garis yang menunjukkan total penjualan dari produk kategori elektronik sebelum dan sesudah diskon.
# python
#
# plt.figure(figsize=(12, 6))
# plt.plot(grouped_sales['sale_date'], grouped_sales['sale_amount'], marker='o', label='Total Penjualan')
# plt.axvline(x='2024-01-01', color='r', linestyle='--', label='Mulai Diskon 20%')
# plt.title('Tren Penjualan Kategori Elektronik')
# plt.xlabel('Tanggal')
# plt.ylabel('Jumlah Penjualan')
# plt.xticks(rotation=45)
# plt.legend()
# plt.show()
# Penjelasan:
# Grafik ini menunjukkan tren penjualan dari waktu ke waktu. Garis merah putus-putus menandakan tanggal dimulainya diskon 20%. Anda dapat melihat apakah ada peningkatan penjualan setelah diskon diterapkan.
# b. Histogram Distribusi Harga Akhir
# Visualisasi:
# Histogram yang menunjukkan distribusi harga akhir setelah diskon.
# python
#
# plt.figure(figsize=(12, 6))
# sns.histplot(sales_data['final_price'], bins=30, kde=True)
# plt.title('Distribusi Harga Akhir Setelah Diskon')
# plt.xlabel('Harga Akhir')
# plt.ylabel('Frekuensi')
# plt.show()
# Penjelasan:
# Histogram ini menunjukkan bagaimana harga akhir produk tersebar setelah penerapan diskon. Puncak histogram dapat menunjukkan rentang harga yang paling umum setelah diskon.
# c. Boxplot Perbandingan Penjualan Sebelum dan Sesudah Diskon
# Visualisasi:
# Boxplot yang membandingkan penjualan sebelum dan sesudah diskon.
# python
#
# plt.figure(figsize=(12, 6))
# sns.boxplot(x='discount', y='final_price', data=sales_data)
# plt.title('Perbandingan Penjualan Sebelum dan Sesudah Diskon')
# plt.xlabel('Diskon (%)')
# plt.ylabel('Harga Akhir')
# plt.xticks([0, 1], ['Sebelum Diskon', 'Setelah Diskon'])
# plt.show()
# Penjelasan:
# Boxplot ini menunjukkan perbandingan harga akhir antara produk yang dijual sebelum dan sesudah diskon. Anda dapat melihat apakah ada perbedaan signifikan dalam harga akhir yang diterima oleh pelanggan.
# 2. Visualisasi untuk Pertanyaan 2: Faktor Utama yang Mempengaruhi Rating Kepuasan Pelanggan
# a. Histogram Distribusi Rating
# Visualisasi:
# Histogram yang menunjukkan distribusi rating pelanggan.
# python
#
# plt.figure(figsize=(12, 6))
# sns.histplot(reviews_data['rating'], bins=5, kde=True)
# plt.title('Distribusi Rating Pelanggan')
# plt.xlabel('Rating')
# plt.ylabel('Frekuensi')
# plt.show()
# Penjelasan:
# Histogram ini menunjukkan bagaimana rating pelanggan tersebar. Puncak pada rating tertentu dapat menunjukkan preferensi pelanggan terhadap produk.
# b. Matriks Korelasi
# Visualisasi:
# Heatmap yang menunjukkan matriks korelasi antara rating dan faktor-faktor lain.
# python
#
# plt.figure(figsize=(10, 8))
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
# plt.title('Matriks Korelasi antara Rating dan Faktor Lain')
# plt.show()
# Penjelasan:
# Heatmap ini menunjukkan hubungan antara rating dan faktor-faktor seperti waktu pengiriman, kualitas produk, dan layanan pelanggan. Nilai mendekati 1 atau -1 menunjukkan hubungan yang kuat.
# c. Scatter Plot Hubungan Rating dan Waktu Pengiriman
# Visualisasi:
# Scatter plot yang menunjukkan hubungan antara waktu pengiriman dan rating.
# python
#
# plt.figure(figsize=(12, 6))
# sns.scatterplot(data=reviews_data, x='delivery_time', y='rating', hue='product_quality', palette='viridis')
# plt.title('Hubungan Antara Waktu Pengiriman dan Rating')
# plt.xlabel('Waktu Pengiriman (Hari)')
# plt.ylabel('Rating')
# plt.show()

# %% [markdown]
# ### Pertanyaan 1:

# %% [markdown]
# ### Pertanyaan 2:

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Analisis Lanjutan (Opsional)
# Pertanyaan 1: Dari visualisasi, Anda dapat menarik kesimpulan tentang efektivitas diskon 20% terhadap penjualan. Jika penjualan meningkat secara signifikan setelah diskon, ini menunjukkan bahwa diskon berhasil menarik lebih banyak pelanggan.
#
# Pertanyaan 2: Dari visualisasi, Anda dapat mengidentifikasi faktor-faktor yang paling berpengaruh terhadap kepuasan pelanggan. Misalnya, jika ada korelasi positif antara waktu pengiriman dan rating, ini menunjukkan bahwa pengiriman yang lebih cepat dapat meningkatkan kepuasan pelanggan.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
# 1. Efektivitas Diskon 20% terhadap Penjualan Produk Kategori Elektronik
# Temuan Utama:
# Tren Penjualan: Grafik garis menunjukkan adanya peningkatan penjualan yang signifikan setelah penerapan diskon 20%. Ini menunjukkan bahwa diskon berhasil menarik lebih banyak pelanggan dan meningkatkan volume penjualan.
# Distribusi Harga Akhir: Histogram distribusi harga akhir setelah diskon menunjukkan bahwa sebagian besar produk dijual pada rentang harga yang lebih rendah, yang dapat menarik lebih banyak pembeli.
# Perbandingan Penjualan: Boxplot menunjukkan perbedaan yang jelas dalam harga akhir antara produk yang dijual sebelum dan sesudah diskon, dengan harga akhir yang lebih rendah setelah diskon.
# Kesimpulan: Diskon 20% terbukti efektif dalam meningkatkan penjualan produk kategori elektronik. Strategi promosi seperti ini dapat dipertimbangkan untuk diterapkan secara berkala untuk meningkatkan penjualan.
# - Conclution pertanyaan 2
# aktor Utama yang Mempengaruhi Rating Kepuasan Pelanggan
# Temuan Utama:
# Distribusi Rating: Histogram distribusi rating menunjukkan bahwa sebagian besar pelanggan memberikan rating yang baik, dengan puncak pada rating tinggi.
# Korelasi Antara Variabel: Heatmap matriks korelasi menunjukkan bahwa ada hubungan positif antara rating dan faktor-faktor seperti kualitas produk dan waktu pengiriman. Ini menunjukkan bahwa pelanggan cenderung memberikan rating yang lebih tinggi jika produk berkualitas baik dan pengiriman cepat.
# Hubungan Waktu Pengiriman dan Rating: Scatter plot menunjukkan bahwa waktu pengiriman yang lebih cepat berhubungan dengan rating yang lebih tinggi, menekankan pentingnya efisiensi dalam pengiriman untuk meningkatkan kepuasan pelanggan.
# Kesimpulan: Faktor-faktor seperti waktu pengiriman dan kualitas produk sangat mempengaruhi kepuasan pelanggan. Perusahaan harus fokus pada peningkatan kualitas produk dan efisiensi pengiriman untuk meningkatkan rating dan kepuasan pelanggan secara keseluruhan.
